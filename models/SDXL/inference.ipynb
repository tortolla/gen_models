# %%
from src.model import SDXLModel
from IPython.display import display

# %%
sdxl = SDXLModel()

# %%
prompt = "A photo of a small cozy cabin in the forest during sunset, ultra detailed, 4k"
negative_prompt = "blurry, low quality, distorted"

images = sdxl.generate(
    prompt=prompt,
    negative_prompt=negative_prompt,
    num_inference_steps=30,
    guidance_scale=7.5,
    seed=1234,
)

img = images[0]
display(img)

# %%
output_path = "data/sample_sdxl.png"
img.save(output_path)
output_path
